# %%
# !yolo task=detect mode=predict model=r'C:\Users\joao.giancoli.PLANOSENG\Desktop\Codigos\RoboflowPlacas\runs\detect\train3\weights\best.pt' conf=0.25 source=r'C:\Users\joao.giancoli.PLANOSENG\Desktop\Codigos\RoboflowPlacas\ERS122_teste.mp4' save=True
# Out:
# Ultralytics YOLOv8.0.189  Python-3.11.6 torch-2.0.1+cpu CPU (Intel Core(TM) i7-10700 2.90GHz)
# Model summary (fused): 168 layers, 3017933 parameters, 0 gradients
#
# video 1/1 (1/3819) C:\Users\joao.giancoli.PLANOSENG\Desktop\Codigos\RoboflowPlacas\ERS122_teste.mp4: 256x640 (no detections), 66.4ms
# video 1/1 (2/3819) C:\Users\joao.giancoli.PLANOSENG\Desktop\Codigos\RoboflowPlacas\ERS122_teste.mp4: 256x640 (no detections), 61.6ms
# video 1/1 (3/3819) C:\Users\joao.giancoli.PLANOSENG\Desktop\Codigos\RoboflowPlacas\ERS122_teste.mp4: 256x640 (no detections), 47.0ms
# video 1/1 (4/3819) C:\Users\joao.giancoli.PLANOSENG\Desktop\Codigos\RoboflowPlacas\ERS122_teste.mp4: 256x640 (no detections), 61.9ms
# video 1/1 (5/3819) C:\Users\joao.giancoli.PLANOSENG\Desktop\Codigos\RoboflowPlacas\ERS122_teste.mp4: 256x640 (no detections), 67.7ms
# video 1/1 (6/3819) C:\Users\joao.giancoli.PLANOSENG\Desktop\Codigos\RoboflowPlacas\ERS122_teste.mp4: 256x640 (no detections), 79.6ms
# ...
